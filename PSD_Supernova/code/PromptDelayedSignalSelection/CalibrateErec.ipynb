# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
from IPython.display import display
plt.style.use(["science","no-latex", "/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle"])
# %config InlineBackend.figure_format = 'svg'
#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

# %%
from LoadMultiFiles import LoadOneFileUproot
from ConcanatePreviousPrediction import GetSelectedDataframe
df_map = GetSelectedDataframe(inf_from_evtType=["evtType", "R", "recE"])

# %%
from HistTools import GetBinCenter
h = plt.hist(df_map[df_map["evtType"]=="IBDd"]["recE"],bins=400)
bins_center = GetBinCenter(h[1])
scale = 2.223/bins_center[np.argmax(h[0])]
print(scale)
plt.semilogy()
plt.xlabel("Reconstruct Energy [ MeV ]")
# Out:
# 0.9999999776918292
# Text(0.5, 0, 'Reconstruct Energy [ MeV ]')

# %%
scale = 0.9218482044800302
print( np.array([2.1,2.7])*scale )
print( np.array([5.2, 5.8])*scale )
# Out:
# [1.93588123 2.48899015]
# [4.79361066 5.34671959]
