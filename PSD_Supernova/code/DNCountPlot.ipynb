# %%
import matplotlib.pylab as plt
import numpy as np
plt.style.use( "/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle")
# %config InlineBackend.figure_format = 'svg'
#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

# %%
with np.load("/afs/ihep.ac.cn/users/l/luoxj/PSD_Supernova/code/DNCount.npz", allow_pickle=True) as f:
    v_TriggerInterval = f["TriggerTimeInterval"]
    v_DN_count = f["DN_count"]

# %%
plt.scatter(  v_TriggerInterval , v_DN_count, s=4)
plt.xlabel("Trigger Time Interval [ us ]")
plt.ylabel("$N_{DarkNoise}$")
plt.title("Check Dark Noise")
plt.semilogx()
from collections import Counter
print(Counter(v_TriggerInterval>10)[True]/len(v_TriggerInterval), v_DN_count[v_TriggerInterval>10],
      v_TriggerInterval[v_TriggerInterval>10])
print(np.where(v_TriggerInterval>10))
# Out:
# 0.00042589437819420784 [4] [54.048]
# (array([593]),)
