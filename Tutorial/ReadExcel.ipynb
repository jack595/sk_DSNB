# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display
plt.style.use(["science","no-latex", "/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle"])
# %config InlineBackend.figure_format = 'svg'
#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

# %%
df = pd.read_excel("/afs/ihep.ac.cn/users/l/luoxj/JUNO_G4_Simulation/optical_run/OneShotSimulation/score.xlsx")

# %%
df = df.iloc[7:]
df
# Out:
#    教学记录表       Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 7      1  2018K8009910008         宋焕智       环境科学       2010         44
# 8      2  2018K8009922012         曾心辰    材料科学与工程       1905          0
# 9      3  2019K8009918004         戴力涵    理论与应用力学       2009         65
# 10     4  2018K8009922007         赵全普    材料科学与工程       2010         74
# 11     5  2020K8009906019         戴亦杨  人文地理与城乡规划       2010         86
# 12     6  2020K8009910013  祖米来提·艾合买提江  人文地理与城乡规划       2010       66.5
# 13     7  2020K8009915004         黄枫凌       生物科学       2004       81.5
# 14     8  2020K8009915006         刘子琛       生物科学       2004         79
# 15     9  2020K8009915010         马梦阳       生物科学       2004       84.5
# 16    10  2020K8009915020         丁楚钧       生物科学       2004       89.5
# 17    11  2020K8009915039         刘博文       生物科学       2004         60
# 18    12  2020K8009915043        张王皓明       生物科学       2004         46
# ...

# %%
sns.histplot(np.array(df["Unnamed: 8"])[:-1], bins=np.arange(0, 110, 5))
plt.xlabel("Score")
# Out:
# Text(0.5, 0, 'Score')

# %%
np.array(df["Unnamed: 8"])
# Out:
# array([26, 18.400000000000002, 48.27142857142857, 54.885714285714286,
#        85.4, 81.55, 54.45, 86.9, 88.15, 79.7642857142857,
#        46.74285714285715, 51.74285714285715, 55.828571428571436,
#        69.0642857142857, 71.02857142857142, 89, 70.07857142857144,
#        69.61428571428571, 83.3, 86.11428571428571, 90.9, 88.15, 84.3,
#        80.5, 50.65714285714286, 83.0142857142857, 88, 78.4, 95.1,
#        85.41428571428571, 80.85, 75.3, 82.9, 90.55, 66.09285714285714,
#        92.65, datetime.datetime(2022, 3, 28, 0, 0)], dtype=object)
