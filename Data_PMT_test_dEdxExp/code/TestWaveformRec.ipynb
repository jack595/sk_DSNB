# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display
plt.style.use(["science","no-latex", "/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle"])
# %config InlineBackend.figure_format = 'svg'
#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

# %%
from importlib import reload
import DataReader
reload(DataReader)
from DataReader import WaveDumpReader,Workflow_WaveformRec, WaveformRec
from copy import copy
# dir_path = {"w/ LED(ch0)":"/afs/ihep.ac.cn/users/l/luoxj/Data_PMT_test_dEdxExp/LED_100ns_2_2V/wave0.dat",
#             "w/o LED(ch0)":"/afs/ihep.ac.cn/users/l/luoxj/Data_PMT_test_dEdxExp/DarkNoise_10min/wave0.dat",
#             "w/ LED(ch1)":"/afs/ihep.ac.cn/users/l/luoxj/Data_PMT_test_dEdxExp/LED_100ns_2_2V/wave1.dat",
#             "w/o LED(ch1)":"/afs/ihep.ac.cn/users/l/luoxj/Data_PMT_test_dEdxExp/DarkNoise_10min/wave1.dat",
#             }
dir_path = {"w/o LED(ch1)":"/afs/ihep.ac.cn/users/l/luoxj/Data_PMT_test_dEdxExp/DarkNoise_10min/wave1.dat"}
dir_df_data = {}
for key,path in dir_path.items():
    df_data = WaveDumpReader(path)
    df_data = df_data[1000:].reset_index()
    df_data_signal = Workflow_WaveformRec(df_data,plot_check=False, threshold_times_std=4)
    del df_data
    dir_df_data[key] = copy(df_data_signal)

# %%
for key,df_data in dir_df_data.items():
    display(df_data)
    for wave in df_data[df_data["valley_min"]<-1]["waveform_sub_base"][:20]:
        # plt.plot(wave)
        plt.figure()
        WaveformRec(wave, plot_check=True)
        plt.xlim(380, 440)
        plt.xlabel("Time [ ns ]")
        plt.ylabel("ADC")
        plt.title("WaveformRec")
# Out:
#      level_0  index  boardID  filePath  channel  pattern  eventCounter  \
# 0          1   1001       31   2084106        1   393216          1064
# 1          2   1002       31   2086188        1   131072          1065
# 2          3   1003       31   2088270        1   262144          1066
# 3          5   1005       31   2092434        1   131072          1068
# 4          8   1008       31   2098680        1   393216          1071
# ..       ...    ...      ...       ...      ...      ...           ...
# 683     1333   2333       31   4857330        1   196608          2396
# 684     1336   2336       31   4863576        1   327680          2399
# 685     1337   2337       31   4865658        1   327680          2400
# 686     1339   2339       31   4869822        1   393216          2402
# 687     1340   2340       31   4871904        1   327680          2403
#
#      triggerTimeTag   triggerTime  \
# 0       34409707113  2.752777e+08
# 1       34460105171  2.756808e+08
# 2       34477697107  2.758216e+08
# 3       34578909381  2.766313e+08
# 4       34744914965  2.779593e+08
# ..              ...           ...
# 683     79468498901  6.357480e+08
# 684     79607801895  6.368624e+08
# 685     79657906439  6.372633e+08
# 686     79811099359  6.384888e+08
# 687     79910508187  6.392841e+08
#
#                                               waveform  \
# 0    [602, 601, 602, 601, 602, 602, 602, 601, 602, ...
# 1    [601, 601, 601, 601, 603, 602, 602, 601, 602, ...
# 2    [602, 602, 602, 602, 602, 602, 602, 602, 602, ...
# 3    [601, 602, 602, 602, 602, 601, 602, 602, 601, ...
# 4    [602, 602, 602, 601, 602, 601, 602, 601, 603, ...
# ..                                                 ...
# 683  [602, 602, 601, 602, 602, 602, 602, 602, 601, ...
# 684  [602, 603, 602, 601, 602, 602, 602, 602, 602, ...
# 685  [602, 603, 603, 602, 602, 602, 601, 601, 601, ...
# 686  [601, 601, 602, 602, 603, 602, 602, 602, 602, ...
# 687  [602, 603, 602, 602, 602, 602, 601, 602, 601, ...
#
#                                      waveform_sub_base                T  \
# 0    [-0.32000000000005, 0.67999999999995, -0.32000...       [402, 826]
# 1    [0.7799999999999727, 0.7799999999999727, 0.779...            [415]
# 2    [-0.2300000000000182, -0.2300000000000182, -0....            [412]
# 3    [0.7400000000000091, -0.2599999999999909, -0.2...            [410]
# 4    [-0.2300000000000182, -0.2300000000000182, -0....            [405]
# ..                                                 ...              ...
# 683  [-0.25, -0.25, 0.75, -0.25, -0.25, -0.25, -0.2...            [412]
# 684  [-0.22000000000002728, -1.2200000000000273, -0...  [392, 655, 683]
# 685  [-0.2699999999999818, -1.2699999999999818, -1....            [402]
# 686  [0.8799999999999955, 0.8799999999999955, -0.12...       [402, 496]
# 687  [-0.20000000000004547, -1.2000000000000455, -0...            [413]
#
#                                                      Q          width  \
# 0               [132.91999999999905, 22.1599999999994]       [19, 12]
# 1                                 [2.3599999999996726]           [12]
# 2                                    [1.4699999999998]           [11]
# 3                                   [17.1400000000001]           [11]
# 4                                  [93.31999999999971]           [16]
# ..                                                 ...            ...
# 683                                            [-1.75]           [11]
# 684  [-14.860000000007176, 1.0599999999992633, 4.49...  [263, 27, 25]
# 685                               [31.520000000000437]           [24]
# 686           [27.719999999999914, 13.319999999999936]       [19, 14]
# 687                                [45.19999999999936]           [14]
#
#                                              amplitude  \
# 0                [53.67999999999995, 9.67999999999995]
# 1                                 [2.7799999999999727]
# 2                                  [2.769999999999982]
# 3                                  [6.740000000000009]
# 4                                  [39.76999999999998]
# ..                                                 ...
# 683                                             [2.75]
# 684  [38.77999999999997, 3.7799999999999727, 2.7799...
# 685                               [11.730000000000018]
# 686            [9.879999999999995, 3.8799999999999955]
# 687                               [13.799999999999955]
#
#                                                 valley  charge_max  width_max  \
# 0               [-2.32000000000005, -0.32000000000005]      132.92         19
# 1                                [-1.2200000000000273]        2.36         12
# 2                                 [-2.230000000000018]        1.47         11
# 3                                 [-1.259999999999991]       17.14         11
# 4                                [-1.2300000000000182]       93.32         16
# ..                                                 ...         ...        ...
# 683                                            [-4.25]       -1.75         11
# 684  [-45.22000000000003, -3.2200000000000273, -2.2...        4.50        263
# 685                              [-1.2699999999999818]       31.52         24
# 686         [-1.1200000000000045, -1.1200000000000045]       27.72         19
# 687                              [-2.2000000000000455]       45.20         14
#
#      amplitude_max  valley_min
# 0            53.68       -2.32
# 1             2.78       -1.22
# 2             2.77       -2.23
# 3             6.74       -1.26
# 4            39.77       -1.23
# ..             ...         ...
# 683           2.75       -4.25
# 684          38.78      -45.22
# 685          11.73       -1.27
# 686           9.88       -1.12
# 687          13.80       -2.20
#
# [688 rows x 20 columns]
