# %%
import matplotlib.pylab as plt
import numpy as np
plt.style.use("/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle")
# %config InlineBackend.figure_format = 'svg'
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

# %%
# print(np.array(f["events"]["EcalEndcapsCollection"]['EcalEndcapsCollection.cellID']))

# print(np.array())
# import uproot4 as up
# f = up.open("/afs/ihep.ac.cn/users/z/zhaoxiao/cms/CEPCSW/Detector/DetCRD/scripts/data/RCEcalSim_535.root")
# v_energy = np.array(f["events"]["EcalBarrelCollection/EcalBarrelCollection.energy"])
# plt.hist(v_energy[0],bins=100)
# plt.xlabel("E")

# %%
import ROOT
# Out:
# 500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e0bb25a851f2> in <module>
#      12 tree = f.Get("Event/Sim/SimEvent")
#      13 print(tree.GetEntries())
# ---> 14 tree.GetEntry(1)
#      15 a = getattr(tree, "SimEvent", None)
#      16
#
# KeyboardInterrupt:
# Error in <TUnixSystem::FindDynamicLibrary>: /cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2/offline/InstallArea/python:/cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2/mt.sniper/InstallArea/python:/cvmfs/juno.ihep.ac.cn/centos7_amd64_g
# cc830/Pre-Release/J21v1r0-Pre2/sniper/InstallArea/python:/cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2/offline/InstallArea/amd64_linux26/lib:/cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2
# ...

# %%
path_root_lib = \
"""/cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2/offline/InstallArea/python:/cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2/mt.sniper/InstallArea/python:/cvmfs/juno.ihep.ac.cn/centos7_amd64_g
cc830/Pre-Release/J21v1r0-Pre2/sniper/InstallArea/python:/cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2/offline/InstallArea/amd64_linux26/lib:/cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2
/mt.sniper/InstallArea/amd64_linux26/lib:/cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2/sniper/InstallArea/amd64_linux26/lib:/cvmfs/juno.ihep.ac.cn/centos7_amd64_gcc830/Pre-Release/J21v1r0-Pre2/ExternalLibs/ROO
T/6.22.08/lib"""
# ROOT.gSystem.AddDynamicPath(path_root_lib)
ROOT.gSystem.AddLinkedLibs(path_root_lib)
ROOT.gSystem.Load("libEDMUtil")
ROOT.gSystem.Load(f"libSimEventV2")
# ROOT.gSystem.Load("libSimHeaderV2")
f = ROOT.TFile.Open("root://junoeos01.ihep.ac.cn//eos/juno/user/luoxj/PSD_LowE/alpha/detsim/root/detsim-992.root")
tree = f.Get("Event/Sim/SimEvent")
print(tree.GetEntries())
tree.GetEntry(1)
a = getattr(tree, "SimEvent", None)

v_cd_hits = a.getCDHitsVec()
for cd_hit in v_cd_hits[:10]:
    print("PMTID:\t",cd_hit.getPMTID()  )
    print("Hit-Time:\t",cd_hit.getHitTime())
    print("Npe:\t", cd_hit.getNPE())
# Out:
# 500
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ddc9afd428ca> in <module>
#      15 a = getattr(tree, "SimEvent", None)
#      16
# ---> 17 v_cd_hits = a.getCDHitsVec()
#      18 for cd_hit in v_cd_hits[:10]:
#      19     print("PMTID:\t",cd_hit.getPMTID()  )
#
# AttributeError: 'SimEvent' object has no attribute 'getCDHitsVec'
# cling::DynamicLibraryManager::loadLibrary(): libBaseEvent.so: cannot open shared object file: No such file or directory
# cling::DynamicLibraryManager::loadLibrary(): libEDMUtil.so: cannot open shared object file: No such file or directory
# cling::DynamicLibraryManager::loadLibrary(): libEDMUtil.so: cannot open shared object file: No such file or directory
# Error in <TInterpreter::TCling::AutoLoad>: failure loading library libSimEventV2.so for JM::SimEvent
# ...
