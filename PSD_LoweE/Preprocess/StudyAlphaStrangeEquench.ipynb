# %%
import matplotlib.pylab as plt
import numpy as np
plt.style.use("/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle")
# %config InlineBackend.figure_format = 'svg'
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

from importlib import reload
import PlotTrackOfProcess
reload(PlotTrackOfProcess)
from PlotTrackOfProcess import PlotTrackOfProcess
track_tool = PlotTrackOfProcess()
track_tool.SetDataset("root://junoeos01.ihep.ac.cn//eos/juno/user/luoxj/PSD_LowE/alpha/detsim/user-root/user-detsim-10.root")

# %%
v_equen = track_tool.Get_v_Equen()
v_edep = track_tool.Get_v_Edep()
index_strange_region = np.where((v_edep<4.2) & (v_edep>4))[0]
index_strange_region_1 = np.where((v_edep<3.8) & (v_edep>3.7))[0]
print(index_strange_region)

track_tool.PlotTrackWithEntrySource(index_strange_region[0],debug=True,brief_show=False,print_track_info=True,
                                    show_process_name=True)
track_tool.PlotTrackWithEntrySource(index_strange_region_1[0],debug=True,brief_show=False,print_track_info=True,
                                    show_process_name=True)
# Out:
# [ 17  24  35  42  48  60 140 146 176 192 196 289 290 320 325 329 334 336
#  342 347 359 381 458 472 481 495]
# Edep:	 4.0072045 ---->
# ####################################################
# pdg:	 1000020040 	momentum:	 172.88376959102962 	created process:	  	, step:	 0.025392458922839405
# Edep:	 3.7581885 ---->
# ####################################################
# pdg:	 1000020040 	momentum:	 167.42313976337502 	created process:	  	, step:	 0.023542442729701733
# {1000020040}
