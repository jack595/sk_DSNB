# %%
import matplotlib.pylab as plt
import numpy as np
plt.style.use("/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle")
# %config InlineBackend.figure_format = 'svg'
#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

from LoadMultiFiles import LoadOneFileUproot

path_file = "proton_no_optical_0_2000MeV_no_tank.root"

dir_events = LoadOneFileUproot(path_file,
                               name_branch="GdLS_log")
dir_geninfo = LoadOneFileUproot(path_file,
                               name_branch="genInfo")

# %%
from importlib import reload

import FunctionFor_dE_dx
reload(FunctionFor_dE_dx)
from FunctionFor_dE_dx import GetDirForNoOpticalAnalyze
pdgID_certain, dir_dE_dx = GetDirForNoOpticalAnalyze(dir_events, dir_geninfo)
plt.hist2d(dir_dE_dx["Einit"]/4,dir_dE_dx["dE_dx"], bins=(100, np.logspace(-1,1, 100)), cmap="Blues")
plt.xlabel("Beam Energy [ MeV/u ]")
plt.ylabel("dE/dx [ MeV/mm ]")
plt.semilogy()

plt.figure()
plt.hist2d(dir_dE_dx["Einit"]/4,dir_dE_dx["dE_dx_main_track"], bins=(100, np.logspace(-1,1, 100)), cmap="Reds")
plt.xlabel("Beam Energy [ MeV/u ]")
plt.ylabel("dE/dx [ MeV/mm ]")
plt.semilogy()
# Out:
# []
