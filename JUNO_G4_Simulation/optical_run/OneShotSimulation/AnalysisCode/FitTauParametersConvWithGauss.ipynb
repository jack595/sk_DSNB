# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display
plt.style.use(["science","no-latex", "/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle"])
# %config InlineBackend.figure_format = 'svg'
#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/JUNO_G4_Simulation/optical_run/OneShotSimulation/AnalysisCode/")

# %%
from LoadMultiFiles import LoadOneFileUproot

df_pars = pd.DataFrame()

# dict_pars = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/JUNO_G4_Simulation/optical_run/OneShotSimulation/particle_dependent/fitResult_theta15_LS_2mm_ConvWithGauss_binned.root", "fitResult", return_list=False)
    # dict_pars = LoadOneFileUproot(f"/afs/ihep.ac.cn/users/l/luoxj/JUNO_G4_Simulation/optical_run/OneShotSimulation/particle_dependent/fitResult_theta15_LS_2mm_ConvWithGauss{option}.root", "fitResult", return_list=False)
dict_pars = LoadOneFileUproot(f"/afs/ihep.ac.cn/users/l/luoxj/JUNO_G4_Simulation/optical_run/OneShotSimulation/particle_dependent/fitResult_theta15_LS_2mm_WithPDF_binned_diffSource.root", "fitResult", return_list=False)
df_pars_tmp = pd.DataFrame.from_dict(dict_pars)
df_pars_tmp["L_LS"] = "2"
df_pars = pd.concat((df_pars, df_pars_tmp))

# dict_time_constant_theta15 = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/JUNO_G4_Simulation/optical_run/OneShotSimulation/particle_dependent/fitResult_theta15_LS_2mm_WithPDF_binned.root","fitResult", return_list=False)
# df_pars_tmp = pd.DataFrame.from_dict(dict_pars)
# df_pars_tmp["L_LS"] = "2"
# df_pars_tmp["source"] = df_pars_tmp["source"]-1
# df_pars = pd.concat((df_pars, df_pars_tmp))

df_pars = df_pars.reset_index()
df_pars
# Out:
#     index  N_nuclei  source      tau1       tau2        tau3        N1  \
# 0       0         2       0  4.593760  20.362037  178.460635  0.761390
# 1       1         2       1  4.641357  21.441704  185.807218  0.766691
# 2       2         4       0  4.791804  21.116168  182.121490  0.769988
# 3       3         4       1  4.830837  21.980473  193.218612  0.772091
# 4       4         6       0  4.754373  21.765213  189.758673  0.762695
# 5       5         6       1  4.738576  21.598099  187.019816  0.767511
# 6       6        10       0  4.944484  24.589569  196.164956  0.753212
# 7       7        10       1  4.927346  22.393732  186.828973  0.779925
# 8       8        12       0  4.751774  24.487177  198.628792  0.724560
# 9       9        12       1  5.076860  23.948145  186.578140  0.768078
# 10     10        14       0  4.745732  25.905125  200.773579  0.701846
# 11     11        14       1  4.716782  21.209281  184.050399  0.765955
# ...

# %%
from importlib import reload
import GlobalFunction
reload(GlobalFunction)
from GlobalFunction import SetdEdxForDataframePars
SetdEdxForDataframePars(df_pars)
# Out:
#     index  N_nuclei  source      tau1       tau2        tau3        N1  \
# 0       0         2       0  4.593760  20.362037  178.460635  0.761390
# 1       1         2       1  4.641357  21.441704  185.807218  0.766691
# 2       2         4       0  4.791804  21.116168  182.121490  0.769988
# 3       3         4       1  4.830837  21.980473  193.218612  0.772091
# 4       4         6       0  4.754373  21.765213  189.758673  0.762695
# 5       5         6       1  4.738576  21.598099  187.019816  0.767511
# 6       6        10       0  4.944484  24.589569  196.164956  0.753212
# 7       7        10       1  4.927346  22.393732  186.828973  0.779925
# 8       8        12       0  4.751774  24.487177  198.628792  0.724560
# 9       9        12       1  5.076860  23.948145  186.578140  0.768078
# 10     10        14       0  4.745732  25.905125  200.773579  0.701846
# 11     11        14       1  4.716782  21.209281  184.050399  0.765955
# ...

# %%
reload(GlobalFunction)
from GlobalFunction import PlotTimeConstantModel, Plot_df_pars
axes = PlotTimeConstantModel()
dict_ylim = {"tau1":(4.5, 5), "N1":(0.6, 0.82), "tau2":(19, 35), "N2":(0.15, 0.3), "tau3":(175, 232), "N3":(0,0.2)}
for j, source in enumerate([ 0]):
    Plot_df_pars(df_pars[df_pars["source"]==source], axes=axes, j=j , source=source, dict_ylim=dict_ylim  )
axes[0].set_title("Fit With $t_{0}$")
# Out:
# Text(0.5, 1.0, 'Fit With $t_{0}$')
