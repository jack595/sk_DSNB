# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display
plt.style.use(["science","no-latex", "/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle"])
# %config InlineBackend.figure_format = 'svg'
#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

# %%
v2d_time_constant = np.loadtxt("/afs/ihep.ac.cn/users/l/luoxj/JUNO_G4_Simulation/build/time_constant_dE_dx.txt")
v_name_timing_constant = ["N1", "tau1", "N2", "tau2", "N3", "tau3"]

print(v2d_time_constant[0])
v_dE_dx = v2d_time_constant[:,0]
dir_v_timing_constant = {}
dir_v_timing_constant["N1"] = v2d_time_constant[:,1]
dir_v_timing_constant["N2"] = v2d_time_constant[:,2]
dir_v_timing_constant["N3"] = v2d_time_constant[:,3]
dir_v_timing_constant["tau1"] = v2d_time_constant[:,4]
dir_v_timing_constant["tau2"] = v2d_time_constant[:,5]
dir_v_timing_constant["tau3"] = v2d_time_constant[:,6]

# Normalization of parameters N*
# for particle in dir_v_timing_constant.keys():
#     for i in range(len(v_name_timing_constant)):
#         if "N" in v_name_timing_constant[i]:
#             dir_v_timing_constant[particle][i] = dir_v_timing_constant[particle][i]*0.01
print(dir_v_timing_constant)


n_figures = len(v_name_timing_constant)
fig,axs = plt.subplots(6,1,sharex="col",figsize=(8,9))
colors = ["b","g","r","c","m","y","k","w"]
dir_v_x = {}
dir_v_y = {}
for i_constant, key in enumerate(dir_v_timing_constant.keys()):
    # plt.figure()
    # ax = plt.subplot(n_figures*100+10+1+i_constant)
    axs[i_constant].plot(v_dE_dx, dir_v_timing_constant[key], color=colors[i_constant], label=key)
    axs[i_constant].scatter(v_dE_dx, dir_v_timing_constant[key], color=colors[i_constant])
    axs[i_constant].legend()

    # axs[i_constant].set_xlim(0,60)
plt.xlabel("dE/dx [ MeV/mm ]")
axs[0].set_title("Time Constant")
# Out:
# [1.00e+00 7.99e-01 1.71e-01 3.00e-02 4.93e+00 2.06e+01 1.90e+02]
# {'N1': array([0.799   , 0.799   , 0.799   , 0.799   , 0.799   , 0.799   ,
#        0.79887 , 0.798354, 0.797839, 0.797323, 0.796808, 0.796292,
#        0.795777, 0.795261, 0.794745, 0.79423 , 0.793714, 0.793199,
#        0.792683, 0.792167, 0.791652, 0.791136, 0.790621, 0.790105,
#        0.789589, 0.789074, 0.788558, 0.788043, 0.787527, 0.787012,
#        0.786496, 0.78598 , 0.785465, 0.784949, 0.784434, 0.783918,
#        0.783402, 0.782887, 0.782371, 0.781856, 0.78134 , 0.780825,
#        0.780309, 0.779793, 0.779278, 0.778762, 0.778247, 0.777731,
#        0.777215, 0.7767  , 0.776184, 0.775669, 0.775153, 0.774638,
#        0.774122, 0.773606, 0.773091, 0.772575, 0.77206 , 0.771544,
#        0.771028, 0.770513, 0.769997, 0.769482, 0.768966, 0.768451,
#        0.767935, 0.767419, 0.766904, 0.766388, 0.765873, 0.765357,
#        0.764841, 0.764326, 0.76381 , 0.763295, 0.762779, 0.762263,
# ...
