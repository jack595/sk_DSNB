# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display
plt.style.use(["science","no-latex", "/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle"])
# %config InlineBackend.figure_format = 'svg'
#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

# %%
from LoadMultiFiles import LoadOneFileUproot
dict_time = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/JUNO_G4_Simulation/optical_run/OneShotSimulation/root_to_fit/time_particle_theta15_LS_2mm_NotSubtractT0.root", name_branch="Data", return_list=False)
dict_pdf = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/JUNO_G4_Simulation/optical_run/OneShotSimulation/root_InstantEmission/time_LS_2mm.root",
                             name_branch="Data", return_list=False)

# %%
bins = np.linspace(0, 30, 200)
plt.hist( dict_pdf["time"][dict_pdf["theta"]==15] ,bins=bins,histtype="step")
plt.hist( dict_time["time"],bins=bins,histtype="step")
plt.semilogy()
# Out:
# []
