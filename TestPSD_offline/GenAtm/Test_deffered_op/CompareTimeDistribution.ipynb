# %%
import matplotlib.pylab as plt
import numpy as np
plt.style.use("/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle")
# %config InlineBackend.figure_format = 'svg'
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

from LoadMultiFiles import LoadOneFileUproot
dir_evt_normal = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/TestPSD_offline/GenAtm/Test_deffered_op/user-normal.root",
                                   name_branch="evt")
dir_evt_deferred_op = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/TestPSD_offline/GenAtm/Test_deffered_op/user-normal_deferred_op.root",
                                        name_branch="evt")
dir_evt_normal_n = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/TestPSD_offline/GenAtm/Test_deffered_op/user-normal_n.root",
                                   name_branch="evt")
dir_evt_deferred_op_n = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/TestPSD_offline/GenAtm/Test_deffered_op/user-normal_n_deferred_op.root",
                                        name_branch="evt")
dir_nCapture_normal_n = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/TestPSD_offline/GenAtm/Test_deffered_op/user-normal_n.root",
                                     name_branch="nCapture")
dir_nCapture_deferred_op_n = LoadOneFileUproot("/afs/ihep.ac.cn/users/l/luoxj/TestPSD_offline/GenAtm/Test_deffered_op/user-normal_n_deferred_op.root",
                                          name_branch="nCapture")

# %%
print(dir_evt_deferred_op.keys())
print(dir_nCapture_normal_n.keys())
# Out:
# dict_keys(['evtID', 'edep', 'edepX', 'edepY', 'edepZ', 'nPhotons', 'totalPE', 'LpmtPE', 'SpmtPE', 'NNVTPE', 'HamaPE', 'CDPE', 'WPPE', 'nPE', 'energy', 'hitTime', 'pmtID', 'PETrackID', 'isCerenkov', 'isReemission', 'isOriginalOP', 'OriginalOPTime', 'nPMTs', 'nPE_byPMT', 'PMTID_byPMT', 'LocalPosX', 'LocalPosY', 'LocalPosZ', 'LocalDirX', 'LocalDirY', 'LocalDirZ', 'GlobalPosX', 'GlobalPosY', 'GlobalPosZ', 'BoundaryPosX', 'BoundaryPosY', 'BoundaryPosZ'])
# dict_keys(['evtID', 'NeutronTrkid', 'NeutronKine', 'NeutronCaptureT', 'NCStartX', 'NCStartY', 'NCStartZ', 'NCStopX', 'NCStopY', 'NCStopZ', 'NCTrackLength', 'trkid', 'pdgid', 'kine', 'px', 'py', 'pz', 'x', 'y', 'z', 't'])

# %%
for option in ["normal", "deferred_op"]:
    locals()["index_Capture_time_cut_"+option] = []
    for v_Capture in locals()["dir_nCapture_"+option+"_n"]["NeutronCaptureT"]:
        locals()["index_Capture_time_cut_"+option].append(np.all(v_Capture>1250))

print(index_Capture_time_cut_normal)
print(index_Capture_time_cut_deferred_op)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
for v_time in dir_evt_deferred_op_n["OriginalOPTime"][:3]:
    hist = plt.hist(v_time,bins=np.linspace(-100,1250,200))
    print(hist[0])

print(dir_nCapture_deferred_op_n["NeutronCaptureT"][0])
# Out:
# [0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 1.227e+03 1.974e+03 7.040e+02 3.420e+02 1.960e+02 1.230e+02
#  1.080e+02 6.800e+01 5.000e+01 3.800e+01 3.200e+01 2.100e+01 2.500e+01
#  3.100e+01 1.600e+01 2.000e+01 2.000e+01 1.300e+01 1.500e+01 1.100e+01
#  9.000e+00 6.000e+00 1.300e+01 1.200e+01 7.000e+00 1.000e+01 7.000e+00
#  5.000e+00 6.000e+00 4.000e+00 8.000e+00 5.000e+00 1.000e+01 5.000e+00
#  6.000e+00 6.000e+00 4.000e+00 5.000e+00 4.000e+00 5.000e+00 1.000e+00
#  3.000e+00 4.000e+00 3.000e+00 4.000e+00 3.000e+00 5.000e+00 6.000e+00
#  3.000e+00 4.000e+00 3.000e+00 3.000e+00 8.000e+00 0.000e+00 5.000e+00
#  2.000e+00 1.000e+00 1.000e+00 2.000e+00 1.000e+00 1.000e+00 1.000e+00
#  0.000e+00 1.000e+00 7.000e+00 1.000e+00 2.000e+00 3.000e+00 0.000e+00
#  2.000e+00 1.000e+00 3.000e+00 2.000e+00 3.000e+00 2.000e+00 0.000e+00
# ...

# %%
plt.hist(np.concatenate(dir_evt_deferred_op["OriginalOPTime"]),bins=np.linspace(-100,1250,200), histtype="step", label="deferred_OP (Electron)", density=True)
plt.hist(np.concatenate(dir_evt_normal["OriginalOPTime"]),bins=np.linspace(-100,1250,200),histtype="step", label="Normal OP (Electron)",density=True)
plt.hist(np.concatenate(np.array(dir_evt_deferred_op_n["OriginalOPTime"])[index_Capture_time_cut_deferred_op]),bins=np.linspace(-100,1250,200), histtype="step", label="deferred_OP (Neutron)", density=True)
plt.hist(np.concatenate(np.array(dir_evt_normal_n["OriginalOPTime"])[index_Capture_time_cut_normal]),bins=np.linspace(-100,1250,200),histtype="step", label="Normal OP (Neutron)",density=True)
plt.semilogy()
plt.legend()
plt.xlabel("OriginalOPTIme [ ns ]")
# Out:
# /tmp/ipykernel_12879/2069107930.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   plt.hist(np.concatenate(np.array(dir_evt_deferred_op_n["OriginalOPTime"])[index_Capture_time_cut_deferred_op]),bins=np.linspace(-100,1250,200), histtype="step", label="deferred_OP (Neutron)", density=True)
# /tmp/ipykernel_12879/2069107930.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ...

# %%
plt.hist(np.concatenate(dir_evt_deferred_op["hitTime"]),bins=np.linspace(-100,1250,200), histtype="step", label="deferred_OP",density=True)
plt.hist(np.concatenate(dir_evt_normal["hitTime"]),bins=np.linspace(-100,1250,200),histtype="step", label="Normal OP",density=True)
plt.hist(np.concatenate(dir_evt_deferred_op_n["hitTime"]),bins=np.linspace(-100,1250,200), histtype="step", label="deferred_OP",density=True)
plt.hist(np.concatenate(dir_evt_normal_n["hitTime"]),bins=np.linspace(-100,1250,200),histtype="step", label="Normal OP",density=True)
plt.semilogy()
plt.legend()
plt.xlabel("hitTime [ ns ]")
# Out:
# Text(0.5, 0, 'hitTime [ ns ]')
