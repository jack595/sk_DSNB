# %%
import matplotlib.pylab as plt
import numpy as np
plt.style.use("/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle")
# %config InlineBackend.figure_format = 'svg'
import sys
sys.path.append("/afs/ihep.ac.cn/users/l/luoxj/root_tool/python_script/")

# %% [markdown]
# # Atm Events ( with Micheal Electron and Neutron Capture )

# %%
name_dir = "/afs/ihep.ac.cn/users/l/luoxj/scratchfs_juno_500G/ProtonDecayML/GenerateAtmNu_no_optical/detsim/"

from importlib import reload
import PlotMichealElectronAndNeutron
import PlotTrackOfProcess
reload(PlotMichealElectronAndNeutron)
reload(PlotTrackOfProcess)
from PlotTrackOfProcess import PlotTrackOfProcess
from PlotMichealElectronAndNeutron import PlotMichealEAndNeutronTools

track_tool = PlotTrackOfProcess()
micheal_e_tool = PlotMichealEAndNeutronTools()

name_file = f"{name_dir}/detsim_user-9992.root"
micheal_e_tool.SetDataset(name_file)
track_tool.SetDataset(name_file)
for i_entry in range(10):
# for i_entry in [4]:
    print(f"######################## Split Event {i_entry} #####################################")
    ax = micheal_e_tool.PlotVertex(i_entry)
    track_tool.PlotTrackWithEntrySource(i_entry,ax=ax,debug=True,
                                    only_plot_parent_particle=True,show_p_direction=False)
    track_tool.PlotTrackWithEntrySource(i_entry,debug=True,
                                        show_p_direction=False)
    print("##################################################################\n")
# Out:
# ######################## Split Event 0 #####################################
# Edep:	 612.7914 ---->
# Edep:	 612.7914 ---->
# ##################################################################
#
# ######################## Split Event 1 #####################################
# Edep:	 850.9786 ---->
# Edep:	 850.9786 ---->
# ##################################################################
#
# ######################## Split Event 2 #####################################
# Edep:	 615.98785 ---->
# Edep:	 615.98785 ---->
# ##################################################################
#
# ######################## Split Event 3 #####################################
# Edep:	 778.4744 ---->
# Edep:	 778.4744 ---->
# ##################################################################
#
# ######################## Split Event 4 #####################################
# Edep:	 476.65372 ---->
# Edep:	 476.65372 ---->
# ##################################################################
#
# ...
