# %%
import matplotlib.pylab as plt
import numpy as np
plt.style.use("/afs/ihep.ac.cn/users/l/luoxj/Style/Paper.mplstyle")
# %config InlineBackend.figure_format = 'svg'
import uproot4 as up
import ROOT
from IPython.display import Image

# %%
Image(filename="./map_reaction.png")

# simevent = up.lazy("/afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/data1/Uedm_1611.root:simevent")
# print(simevent["t_pdgid"][4])

# %%
# geninfo = up.lazy("/afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_11*.root:PickEvt")
# print(geninfo["interType"])
geninfo_chain = ROOT.TChain("PickEvt")
geninfo_chain.SetBranchStatus("*", 0)
geninfo_chain.SetBranchStatus("interType", 1)
geninfo_chain.SetBranchStatus("evtID", 1)
geninfo_chain.SetBranchStatus("ctag", 1)
for i in range(10):
    geninfo_chain.Add(f"/afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_{i}.root")

# %%
entries_geninfo = geninfo_chain.GetEntries()
print(entries_geninfo)
# Out:
# 80
# Error in <TFile::TFile>: file /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_0.root does not exist
# Error in <TFile::TFile>: file /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_1.root does not exist

# %%
# for i in range(entries_geninfo):
for i in range(entries_geninfo):
    geninfo_chain.GetEntry(i)
    if geninfo_chain.interType == 1 and geninfo_chain.ctag==2:
        print(geninfo_chain.evtID,geninfo_chain.interType, geninfo_chain.ctag)
        print(geninfo_chain.GetCurrentFile().GetName())
        print(geninfo_chain.LoadTree(i))
# Out:
# 176711 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_2.root
# 2
# 251382 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_2.root
# 5
# 48691 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_2.root
# 6
# 121639 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_2.root
# 7
# 50979 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_3.root
# 2
# 20892 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_3.root
# 3
# 178939 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_3.root
# 4
# 199977 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_3.root
# 7
# 57424 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_4.root
# 1
# 396302 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_4.root
# 2
# 283511 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_4.root
# 3
# 176496 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_4.root
# 4
# 256940 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_4.root
# 5
# 159030 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_4.root
# 8
# 248327 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_5.root
# 2
# 143756 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_5.root
# 3
# 16926 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_6.root
# 1
# 246999 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_6.root
# 3
# 252701 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_6.root
# 4
# 306484 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_6.root
# 5
# 294028 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_6.root
# 7
# 352675 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_7.root
# 5
# 134298 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_7.root
# 6
# 97196 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_8.root
# 0
# 248444 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_8.root
# 1
# 310970 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_8.root
# 2
# 160703 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_9.root
# 4
# 54973 1 2
# /afs/ihep.ac.cn/users/l/luoxj/ProtonDecayML/Atm_hu/geninfo/geninfo_9.root
# 8
